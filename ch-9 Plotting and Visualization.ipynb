# %%
import pandas as pd
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
from numpy.random import randn
import seaborn as sns

# %%
# fig = plt.figure()

# %%
#

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax1.plot(np.random.randn(50).cumsum(),'k--')
_ = ax2.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)

fg = ax3.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))
fig
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig1,axes1 = plt.subplots(2,3)
# fig1
axes1
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# plt.hist(np.arange(30),bins=20,sharex=[5,10,15,20,25,300])
# plt.hist(np.arange(30),bins=20,sharex=True)

# %%
# subplots_adjust(left=None, bottom=None, right=None, top=None,
#                 wspace=None, hspace=None)

# fig,axes = plt.subplots(2,2,sharex=True,sharey=True)
# for i in range(2):
#     for j in range(2):
#         axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)
# plt.subplots_adjust(wspace=0,hspace=0.001)

# %%
# ax.plot(x, y, linestyle='--', color='g')  ploting with some coloring and linestyling with x and y as variable

# %%
from numpy.random import randn

gh = plt.plot(randn(30).cumsum(),'ko--')
# gh.show()
gh
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(randn(30).cumsum(), 'ko--')
# plt.show()

# %%
data = randn(50).cumsum()
data
# randn(10).cumsum()
fig1 = plt.plot(data,'k--',label='Default')
fig2 = plt.plot(data,'k-',drawstyle='steps-post',label='step-post')

plt.legend(loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
fig = plt.figure()
fg = fig.add_subplot(1,1,1)

fg.plot(randn(1000))
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
ticks = fg.set_xticks([0,250,500,750,1000])
labels = fg.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')

# %%
title =fg.set_title("My first plot title")
fg.set_xlabel('stages')
# Out:
# Text(0.5, 15.528422124795624, 'stages')

# %%
props = {
    'title': 'My first matplotlib plot',
    'xlabel': 'Stages'
}
fg.set(**props)
# Out:
# [Text(0.5, 1.0, 'My first matplotlib plot'),
#  Text(0.5, 15.528422124795624, 'Stages')]

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k.', label='two')
ax.plot(randn(1000).cumsum(), 'k--', label='three')
ax.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
data
# Out:
# <img src="data:image/png;base64,..." width="640">
#                 SPX
# 1990-02-01   328.79
# 1990-02-02   330.92
# 1990-02-05   331.85
# 1990-02-06   329.66
# 1990-02-07   333.75
# ...             ...
# 2011-10-10  1194.89
# 2011-10-11  1195.54
# 2011-10-12  1207.25
# 2011-10-13  1203.66
# 2011-10-14  1224.58
#
# [5472 rows x 1 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
plt.savefig('figpath.pdf', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

data = pd.read_csv('spx.csv',index_col=0,parse_dates=True)
spx = data['SPX']
# spx.loc['1990-02-01']
spx.plot(ax=ax,style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]
crisis_data


for date, label in crisis_data:
#     s=spx.asof(date)  it is same as spx[date]        
    ax.annotate(label ,xy = (date,spx.asof(date)+75),
               xytext = (date,spx.asof(date)+225),
                arrowprops=dict(facecolor='black',headwidth=4,headlength=4,width=2),
                horizontalalignment='left',verticalalignment='top' 
               )
ax.set_ylim([600,1800])
ax.set_xlim(['1/1/2007','1/1/2011'])

plt.title("2008 financial crisis main dates")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, '2008 financial crisis main dates')

# %%
plt.rc('figure',figsize=(5,5))

# font_options = {'family' : 'monospace',
#                 'weight' : 'bold',
#                 'size'   : 'small'}
# plt.rc('font', **font_options)

# %% [markdown]
# matplotlib comes with a configuration file matplotlibrc in the matplotlib/mpl-data directory. If you customize this file and place it in your home directory titled .matplotlibrc, it will be loaded each time you use matplotlib.

# %%
s=pd.Series(randn(20),index=np.arange(20))
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="500">
# <AxesSubplot:>

# %%
df = pd.DataFrame(randn(20).reshape(4,5),columns=['a','b','c','d','e'],index=np.arange(4))
df.plot()
random_seed=42
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(2,1)

data = pd.Series( np.random.rand(16),index=list("abcdefghijklmnop"))

fg1 = data.plot.bar(ax=axes[0],color='r',alpha=0.7)
fg2 = data.plot.barh(ax=axes[1],color='y',alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame(np.random.rand(6, 4),
   ....:                   index=['one', 'two', 'three', 'four', 'five', 'six'],
   ....:                   columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
df.plot.bar()
plt.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.barh(stacked=True,alpha=0.5)
df.value_counts
# Out:
# <img src="data:image/png;base64,..." width="640">
# <bound method DataFrame.value_counts of Genus         A         B         C         D
# one    0.910867  0.355652  0.749931  0.340130
# two    0.707624  0.670816  0.363661  0.721933
# three  0.464109  0.823235  0.557744  0.555200
# four   0.385916  0.220447  0.521308  0.679597
# five   0.026708  0.463089  0.513355  0.654593
# six    0.540403  0.665921  0.675402  0.142091>

# %%
tips = pd.read_csv("tips.csv")
t=tips.head()

party_size = pd.crosstab(tips['day'],tips['size'])
party_size
# t['size'].()
# tips[tips['day']=='Sun']
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_size.loc[:,2:5]
party_pcts = party_counts.div(party_counts.sum(1), axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_counts.sum(1)
# Out:
# day
# Fri     18
# Sat     85
# Sun     75
# Thur    58
# dtype: int64

# %%
party_pcts.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='day'>

# %%
tips['tip_pct'] = tips['tip']/(tips['total_bill']-tips['tip'])
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.172069
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.190114
#
# [244 rows x 8 columns]

# %%
sns.barplot(x="tip_pct",y="day",data=tips,orient='h')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
sns.barplot(x='tip_pct', y='day', hue='sex', data=tips, orient='h')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
tips['tip_pct'].plot.density()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Density'>

# %%
cmp1 = np.random.normal(0,1,size=200)
cmp2 = np.random.normal(10,2,size=200)

cmp= np.concatenate([cmp1,cmp2])
cmp
# pt = sns.distplot(cmp,bins=50,color='g')  ### warning distplot is disabled in future
pt = sns.histplot(cmp,bins=50,color='g')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
macro = pd.read_csv("macro_data.csv")
macro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      203 non-null    float64
#  1   quarter   203 non-null    float64
#  2   realgdp   203 non-null    float64
#  3   realcons  203 non-null    float64
#  4   realinv   203 non-null    float64
#  5   realgovt  203 non-null    float64
#  6   realdpi   203 non-null    float64
#  7   cpi       203 non-null    float64
#  8   m1        203 non-null    float64
#  9   tbilrate  203 non-null    float64
#  10  unemp     203 non-null    float64
#  11  pop       203 non-null    float64
#  12  infl      203 non-null    float64
#  13  realint   203 non-null    float64
# dtypes: float64(14)
# memory usage: 22.3 KB

# %%
data = macro[['cpi','m1','tbilrate','unemp']]

trans_data = np.log(data).diff().dropna()
trans_data
np.log(data).diff()
# data
g = np.array([[1,2,3],[4,5,6]])
np.log(data)
sns.regplot(data=trans_data,x='m1',y='unemp')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='m1', ylabel='unemp'>

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
sns.catplot(x='day',y='tip_pct',hue='time',data= tips[tips['tip_pct']<1],col='sex',kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="1096">

# %%
sns.catplot(x='day',y='tip_pct',row='time',data= tips[tips['tip_pct']<1],col='sex',kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
np.min(tips.tip_pct)
sns.catplot(x='tip_pct',y='day',data= tips[tips['tip_pct']<0.5],kind='box')
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# # seborn.FacetGrid()    
# for more info 
# https://seaborn.pydata.org/

# %% [markdown]
# others tools for data visualization
#
# http://bokeh.pydata.org/
#
# https://github.com/plotly/plotly.py
